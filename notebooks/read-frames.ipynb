# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
pressure = np.load("../resources/data/frames/pressure_0001.npy")
alpha = np.load("../resources/data/frames/occupancy_0001.npy")
pressure.shape, alpha.shape
# Out:
# ((1024, 64, 64), (1024, 64, 64))

# %%
plt.imshow(pressure[256], vmin=-10, vmax=10)

# %%
plt.imshow(alpha[256])
